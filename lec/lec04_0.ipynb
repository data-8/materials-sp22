# %%
from datascience import *
import numpy as np

# %% [markdown]
# ### Why Names?

# %% [markdown]
# A cell with arithmetic but no names is difficult to interpret.

# %%
# Option 1
40 * 15.00
# Out:
# 600.0

# %%
40 * 52 * 15.00
# Out:
# 31200.0

# %% [markdown]
# On January 1, 2022, the CA Minimum Wage for Employers with 26 Employees or More increased to $15/hour.

# %%
# Option 2
ca_hourly_minimum_wage = 15.00
hours_per_week = 40
weeks_per_year = 52

# %%
hours_per_year = hours_per_week * weeks_per_year

# %%
hours_per_year
# Out:
# 2080

# %%
weekly_wages = hours_per_week * ca_hourly_minimum_wage
weekly_wages
# Out:
# 600.0

# %%
yearly_wages = hours_per_year * ca_hourly_minimum_wage
yearly_wages
# Out:
# 31200.0

# %% [markdown]
# ## Numbers ##

# %%
10 * 3
# Out:
# 30

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 / 3 + 10 / 3
# Out:
# 6.666666666666667

# %%
10 ** 3
# Out:
# 1000

# %%
10 ** 0.5
# Out:
# 3.1622776601683795

# %%
1234567 ** 890
# Out:
# ...

# %%
382764238764.238742034876503865238723985
# Out:
# 382764238764.2388

# %%
382764238764.238742034876503865238723985 - 382764238764.238742
# Out:
# 0.0

# %%
6 / 4000000000000000000000000000000
# Out:
# 1.5e-30

# %%
(13 ** 0.5)
# Out:
# 3.605551275463989

# %%
(13 ** 0.5) * (13 ** 0.5)
# Out:
# 12.999999999999998

# %%
3.605551275463989 * 3.605551275463989
# Out:
# 12.999999999999998

# %%
4000000000000000000000000000000 * (6 / 4000000000000000000000000000000)
# Out:
# 6.0

# %%
10/3 * 10000000000000000000000000000
# Out:
# 3.3333333333333333e+28

# %%
6/4
# Out:
# 1.5

# %%
(13 ** 0.5) ** 2
# Out:
# 12.999999999999998

# %%
123456789123456789.0
# Out:
# 1.2345678912345678e+17

# %% [markdown]
# ## Strings ##

# %%
'Flavor'
# Out:
# 'Flavor'

# %%
Flavor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c281a38ccebf> in <module>
# ----> 1 Flavor
#
# NameError: name 'Flavor' is not defined

# %%
'Vanilla Flavor'
# Out:
# 'Vanilla Flavor'

# %%
'234'
# Out:
# '234'

# %%
'Don't put apstrophes in a string'
# Out:
#   File "<ipython-input-42-60bb94a2e42d>", line 1
#     'Don't put apstrophes in a string'
#          ^
# SyntaxError: invalid syntax

# %%
"Don't put apstrophes in a string"
# Out:
# "Don't put apstrophes in a string"

# %%
"Don't put apstrophes in a string"
# Out:
# "Don't put apstrophes in a string"

# %%
"in a "quoted" string"
# Out:
#   File "<ipython-input-46-1f8dfbc0aecd>", line 1
#     "in a "quoted" string"
#            ^
# SyntaxError: invalid syntax

# %%
"hello"
# Out:
# 'hello'

# %%
hi = "hello"

# %%
hi
# Out:
# 'hello'

# %%
'hello' + 'students'
# Out:
# 'hellostudents'

# %%
'hello' + ' ' + 'students'
# Out:
# 'hello students'

# %%
hi + ' students'
# Out:
# 'hello students'

# %%
'ha' * 10
# Out:
# 'hahahahahahahahahaha'

# %%
'ha' * 'ha'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-2451ceb36a89> in <module>
# ----> 1 'ha' * 'ha'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
str(3)
# Out:
# '3'

# %%
'my kid is ' + str(5)
# Out:
# 'my kid is 5'

# %%
'23'
# Out:
# '23'

# %%
int('23') + 1
# Out:
# 24

# %%
float('23.45')
# Out:
# 23.45

# %%
float('23.45.67')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-4fe5f12b82e4> in <module>
# ----> 1 float('23.45.67')
#
# ValueError: could not convert string to float: '23.45.67'

# %%
int('23.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-39578872d7d4> in <module>
# ----> 1 int('23.45')
#
# ValueError: invalid literal for int() with base 10: '23.45'

# %%
float(23.45)
# Out:
# 23.45

# %%
int(123.90)
# Out:
# 123

# %%
x = 'ha'
x * 10
# Out:
# 'hahahahahahahahahaha'

# %%
float(1)
# Out:
# 1.0

# %% [markdown]
# ## Types ##

# %%
type(10)
# Out:
# int

# %%
x = 10

# %%
type(4.5)
# Out:
# float

# %%
type(1.0)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
from datascience import *

# %%
type(Table.read_table('nba_salaries.csv'))
# Out:
# datascience.tables.Table

# %%
abs(-5)
# Out:
# 5

# %%
abs
# Out:
# <function abs(x, /)>

# %%
type(abs)
# Out:
# builtin_function_or_method

# %% [markdown]
# ## Arrays ##

# %%
first_four = make_array(1, 2, 3, 4)

# %%
first_four
# Out:
# array([1, 2, 3, 4])

# %%
type(first_four)
# Out:
# numpy.ndarray

# %%
np.average(first_four)
# Out:
# 2.5

# %%
np.sum(first_four)
# Out:
# 10

# %%
first_four + 3
# Out:
# array([4, 5, 6, 7])

# %%
first_four * 2
# Out:
# array([2, 4, 6, 8])

# %%
first_four ** 2
# Out:
# array([ 1,  4,  9, 16])

# %%
second_four = make_array(5, 6, 7, 8)

# %%
first_four + second_four
# Out:
# array([ 6,  8, 10, 12])

# %%
first_four
# Out:
# array([1, 2, 3, 4])

# %%
only_three = make_array(9, 10, 11)

# %%
first_four + only_three
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-8c77c7c9aafb> in <module>
# ----> 1 first_four + only_three
#
# ValueError: operands could not be broadcast together with shapes (4,) (3,)

# %%
first_four * second_four
# Out:
# array([ 5, 12, 21, 32])

# %%
s = make_array('hi', 'he', 'ho')

# %%
len(s)
# Out:
# 3

# %%
s.item(0)
# Out:
# 'hi'

# %%
s.item(1)
# Out:
# 'he'

# %%
s.item(2)
# Out:
# 'ho'

# %%
first_four
# Out:
# array([1, 2, 3, 4])

# %%
first_four.item(0)
# Out:
# 1

# %%
second_four
# Out:
# array([5, 6, 7, 8])

# %%
second_four.item(0)
# Out:
# 5

# %%
second_four.item(1)
# Out:
# 6

# %%
second_four.item(2)
# Out:
# 7

# %%
second_four.item(7)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-eab7b988ca23> in <module>
# ----> 1 second_four.item(7)
#
# IndexError: index 7 is out of bounds for axis 0 with size 4

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
nba = Table.read_table('nba_salaries.csv').where('season', 2020).drop('season')
nba.show(5)

# %%
warriors = nba.where('team', 'Golden State Warriors')
warriors.show(5)
